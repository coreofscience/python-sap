# %%
from sap import load, Sap, CachedCollection
filename = 'data/sample.isi'
sap = Sap()
graph = next(load(CachedCollection.from_filenames(filename)))
tree = sap.tree(graph)

from sap.widget import display

# %%
display(tree)
# Out:
# <style type="text/css">
#     .Tree {
#         font-family: Helvetica, Arial, Sans-Serif;
#         width: 100%;
#     }
#
#     .Tree-segment {
#         --color: 245, 162, 0;
#         margin-bottom: 15px;
#         display: flex;
#         flex-direction: row;
#     }
#
#     .Tree-segment-info {
#         width: 50px;
#     }
#
#     .Tree-segment-articles {
#         flex-grow: 1;
#     }
#
#     .Info {
#         z-index: 10;
#         position: relative;
#         top: 10px;
#         left: 5px;
#         width: 250px;
#         background-color: rgb(var(--color));
#         padding: 20px;
#         border-radius: 20px;
#         clip-path: circle(20px at 20px 20px);
#         color: white;
#         transition: clip-path 0.5s ease-in-out;
#         box-shadow: 0 3px 5px -5px black;
#     }
#
#     .Info:hover {
#         clip-path: circle(80%);
#     }
#
#     .Tree-segment.root {
#         --color: 245, 162, 0;
#     }
#
#     .Tree-segment.trunk {
#         --color: 130, 77, 30;
#     }
#
#     .Tree-segment.leave {
#         --color: 76, 172, 51;
#     }
#
#     .Article {
#         transition: background 0.5s ease;
#         box-shadow: 0 3px 5px -5px black;
#         margin-top: 5px;
#         padding: 15px;
#         width: calc(100% - 30px);
#         border-left: 5px solid rgb(var(--color));
#         position: relative;
#     }
#
#     .Article::after {
#         content: " ";
#         display: block;
#         position: absolute;
#         width: 0;
#         height: 0;
#         border-top: 2.5px solid transparent;
#         border-bottom: 2.5px solid transparent;
#         border-left: 2.5px solid rgb(var(--color));
#         left: 0px;
#         top: calc(50% - 2.5px);
#         transition: transform 0.5s ease-in-out;
#         transform-origin: 0 50%;
#         transform: scale(0, 0);
#     }
#
#     .Article:hover::after {
#         transform: scale(1, 1);
#     }
#
#     .Article:hover {
#         background-color: rgba(var(--color), 0.1);
#     }
#
#     a.Article-doi {
#         text-decoration: none;
#         color: lightseagreen;
#         filter: brightness(60%);
#         transition: all 0.5 ease-in-out;
#     }
#
#     a.Article-doi {
#         filter: brightness(90%);
#     }
# </style>
# <div class="Tree">
#     <div class="Tree-segment root">
#         <div class="Tree-segment-info">
#             <div class="Info">
#                 <h3>Root</h3>
#                 <p>
#                     Here you should find seminal articles from the original
#                     articles of your topic of interest.
#                 </p>
#             </div>
#         </div>
#         <div class="Tree-segment-articles">
#             <div class="Article-collection"><div class="Article" id="Terblanché F. C., 1996, Journal of Essential Oil Research, V8, P471"><span class="Article-authors">Terblanché F C.</span> <span class="Article-year">(1996)</span>. <em><span class="Article-journal">Journal Of Essential Oil Research</span>, <span class="Article-volume">8</span></em>, <span class="Article-page">471</span>.</div><div class="Article" id="Adams R. P., 1995, IDENTIFICATION ESSEN"><span class="Article-authors">Adams R P.</span> <span class="Article-year">(1995)</span>. <em><span class="Article-journal">Identification Essen</span></em>.</div><div class="Article" id="Adams R.P., 2001, IDENTIFICATION ESSEN"><span class="Article-authors">Adams RP.</span> <span class="Article-year">(2001)</span>. <em><span class="Article-journal">Identification Essen</span></em>.</div><div class="Article" id="LEMOS TLG, 1990, PHYTOTHER RES, V4, P82, DOI 10.1002/ptr.2650040210"><span class="Article-authors">Lemos TLG.</span> <span class="Article-year">(1990)</span>. <em><span class="Article-journal">Phytother Res</span>, <span class="Article-volume">4</span></em>, <span class="Article-page">82</span>. <a class="Article-doi" href="https://dx.doi.org/10.1002/ptr.2650040210" target="_blank" rel="noreferrer">https://dx.doi.org/10.1002/ptr.2650040210</a></div><div class="Article" id="Burt S, 2004, INT J FOOD MICROBIOL, V94, P223, DOI 10.1016/j.ijfoodmicro.2004.03.022"><span class="Article-authors">Burt S.</span> <span class="Article-year">(2004)</span>. <em><span class="Article-journal">Int J Food Microbiol</span>, <span class="Article-volume">94</span></em>, <span class="Article-page">223</span>. <a class="Article-doi" href="https://dx.doi.org/10.1016/j.ijfoodmicro.2004.03.022" target="_blank" rel="noreferrer">https://dx.doi.org/10.1016/j.ijfoodmicro.2004.03.022</a></div><div class="Article" id="Adams R. P., 2007, IDENTIFICATION ESSEN"><span class="Article-authors">Adams R P.</span> <span class="Article-year">(2007)</span>. <em><span class="Article-journal">Identification Essen</span></em>.</div><div class="Article" id="Bakkali F, 2008, FOOD CHEM TOXICOL, V46, P446, DOI 10.1016/j.fct.2007.09.106"><span class="Article-authors">Bakkali F.</span> <span class="Article-year">(2008)</span>. <em><span class="Article-journal">Food Chem Toxicol</span>, <span class="Article-volume">46</span></em>, <span class="Article-page">446</span>. <a class="Article-doi" href="https://dx.doi.org/10.1016/j.fct.2007.09.106" target="_blank" rel="noreferrer">https://dx.doi.org/10.1016/j.fct.2007.09.106</a></div><div class="Article" id="Lacoste E., 1996, Annales Pharmaceutiques Francaises, V54, P228"><span class="Article-authors">Lacoste E.</span> <span class="Article-year">(1996)</span>. <em><span class="Article-journal">Annales Pharmaceutiques Francaises</span>, <span class="Article-volume">54</span></em>, <span class="Article-page">228</span>.</div><div class="Article" id="VANDENDOOL H, 1963, J CHROMATOGR, V11, P463, DOI 10.1016/S0021-9673(01)80947-X"><span class="Article-authors">Vandendool H.</span> <span class="Article-year">(1963)</span>. <em><span class="Article-journal">J Chromatogr</span>, <span class="Article-volume">11</span></em>, <span class="Article-page">463</span>. <a class="Article-doi" href="https://dx.doi.org/10.1016/S0021-9673(01)80947-X" target="_blank" rel="noreferrer">https://dx.doi.org/10.1016/S0021-9673(01)80947-X</a></div><div class="Article" id="MATOS F. J. A, 1996, J ESSENT OIL RES, V8, P695"><span class="Article-authors">Matos F J A.</span> <span class="Article-year">(1996)</span>. <em><span class="Article-journal">J Essent Oil Res</span>, <span class="Article-volume">8</span></em>, <span class="Article-page">695</span>.</div><div class="Article" id="Lambert RJW, 2001, J APPL MICROBIOL, V91, P453, DOI 10.1046/j.1365-2672.2001.01428.x"><span class="Article-authors">Lambert RJW.</span> <span class="Article-year">(2001)</span>. <em><span class="Article-journal">J Appl Microbio ...
